# %% [markdown]
# <a href="https://colab.research.google.com/github/Jinyong-20/Machine_Learning_Programming/blob/master/PyCharm_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from PIL import Image

# %%
Image.open('1.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1921x1040 at 0x7F0FD74866D8>

# %% [markdown]
# \# breakpoint를 설정하고 싶으면 코드 줄을 클릭하면 빨간색 동그라미가 뜨며, 디버그시 그 라인에서 스탑하고 value를 확인할 수 있습니다.

# %%
Image.open('2.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1917x1005 at 0x7F0FD73D2CF8>

# %% [markdown]
# \#  plt 관련 기능에서 Error: failed to send plot to http://127.0.0.1:63342 라는 오류가 발생합니다

# %%
Image.open('3.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1915x1040 at 0x7F0FD73D2C18>

# %% [markdown]
# \# 초반부 주석

# %%
Image.open('4.PNG')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1913x1035 at 0x7F0FD73D2F28>

# %% [markdown]
# \# 초반부 주석2

# %% [markdown]
# 이후 내용은 공부할 내용 없이 스스로 독학하기에 무리라고 판단하였습니다. 최소한의 자료라도 주어저야 학습할 수 있을 것 같습니다. 교재를 사야할까요?

# %% [markdown]
# *GAN 코드 코멘트 해야 합니다. 이제 pycharm 쓰는 것을 잘 하셨는데 이제 GAN 구조를 이해해야 합니다.교재는 https://github.com/moonryul/pytorchBookCode 여기 교수님이 올렸습니다 ~*
